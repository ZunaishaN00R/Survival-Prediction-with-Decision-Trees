# %% [markdown]
#  **Build decision tree model to predict survival based on certain parameters CSV file is provided
# to you. In this file using following columns build a model to predict if person would survive or not,
# ▪ Pclass
# ▪ Sex
# ▪ Age
# ▪ Fare
# ▪ Calculate score of your model**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
df = pd.read_csv("/content/titanic.csv")

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 1   PC 17599  71.2833   C85        C

# %%
df.dropna(subset=["Pclass", "Sex", "Age", "Fare", "Survived"], inplace=True)

# %%
label_encoder = LabelEncoder()
df["Sex"] = label_encoder.fit_transform(df["Sex"])

# %%
X = df[["Pclass", "Sex", "Age", "Fare"]]
y = df["Survived"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of the Decision Tree model: {accuracy:.2f}")
# Out:
# Accuracy of the Decision Tree model: 0.80

# %%
plt.figure(figsize=(35, 35))
plot_tree(clf, feature_names=X.columns, class_names=["Not Survived", "Survived"],
          filled=True, rounded=True, fontsize=10)
plt.title("Decision Tree Visualization")
plt.show()
